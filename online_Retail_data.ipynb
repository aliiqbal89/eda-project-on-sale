# %% [markdown]
# ## Data Analysis project online Retail

# %%
# Introduction
# Project Overview
# Data Cleaning
# Sales Analysis
# Customer Segmentation
# Churn Analysis
# Large Scale Data Analysis using Fireducks

# %%
# !pip install openpyxl

import pandas as pd
from matplotlib import pyplot as plt

# %%
##Data load

# %%
# !wget https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Out:
# --2025-04-28 21:27:35--  https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘online+retail.zip’
#
# online+retail.zip       [    <=>             ]  22.62M  31.7MB/s    in 0.7s
#
# 2025-04-28 21:27:37 (31.7 MB/s) - ‘online+retail.zip’ saved [23715478]

# %%
# !unzip online+retail.zip
# Out:
# Archive:  online+retail.zip
#  extracting: Online Retail.xlsx

# %%
df1 = pd.read_excel('Online Retail.xlsx', dtype={'InvoiceNo':'string','StockCode':'string','Description':'string','	Country':'string'})
df1.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df1.shape
# Out:
# (541909, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  string
#  1   StockCode    541909 non-null  string
#  2   Description  540455 non-null  string
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(1), string(3)
# memory usage: 33.1+ MB

# %% [markdown]
# ##Data Cleaning Handle missing Values

# %%
df1.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df1[df1['Description'].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139        <NA>        56 2010-12-01 11:52:00
# 1970      536545     21134        <NA>         1 2010-12-01 14:32:00
# 1971      536546     22145        <NA>         1 2010-12-01 14:33:00
# 1972      536547     37509        <NA>         1 2010-12-01 14:33:00
# 1987      536549    85226A        <NA>         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581        <NA>        -2 2011-12-07 18:26:00
# 535326    581203     23406        <NA>        15 2011-12-07 18:31:00
# 535332    581209     21620        <NA>         6 2011-12-07 18:35:00
# 536981    581234     72817        <NA>        27 2011-12-08 10:33:00
# 538554    581408     85175        <NA>        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# ...

# %%
df1[df1.StockCode=="22139"]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 106       536381     22139  RETROSPOT TEA SET CERAMIC 11 PC         23
# 622       536414     22139                              <NA>        56
# 6392      536942     22139                            amazon        15
# 6885      536982     22139  RETROSPOT TEA SET CERAMIC 11 PC         10
# 7203      537011     22139                              <NA>        -5
# ...          ...       ...                               ...       ...
# 538411    581405     22139  RETROSPOT TEA SET CERAMIC 11 PC          1
# 539531    581439     22139  RETROSPOT TEA SET CERAMIC 11 PC          1
# 540441    581486     22139  RETROSPOT TEA SET CERAMIC 11 PC          6
# 541387    581498     22139  RETROSPOT TEA SET CERAMIC 11 PC          2
# 541726    581570     22139  RETROSPOT TEA SET CERAMIC 11 PC          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df1[df1.StockCode=='22139'].Description.mode()
# Out:
# 0    RETROSPOT TEA SET CERAMIC 11 PC
# Name: Description, dtype: string

# %%
most_freq = df1[['StockCode','Description']].value_counts().reset_index()
most_freq  # this shows the most freq product
# Out:
#      StockCode                         Description  count
# 0       85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423            REGENCY CAKESTAND 3 TIER   2200
# 2       85099B             JUMBO BAG RED RETROSPOT   2159
# 3        47566                       PARTY BUNTING   1727
# 4        20725             LUNCH BAG RED RETROSPOT   1638
# ...        ...                                 ...    ...
# 4787     21491     SET OF THREE VINTAGE GIFT WRAPS      1
# 4788    84876D                             damaged      1
# 4789     20827                             damages      1
# 4790     20832                               check      1
# 4791     21578                                   ?      1
#
# [4792 rows x 3 columns]

# %%
most_freq[most_freq.StockCode=='85123A'].reset_index().head(1)
# Out:
#    index StockCode                         Description  count
# 0      0    85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302

# %%
most_freq.groupby("StockCode").head(1)
# Out:
#      StockCode                          Description  count
# 0       85123A   WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423             REGENCY CAKESTAND 3 TIER   2200
# 2       85099B              JUMBO BAG RED RETROSPOT   2159
# 3        47566                        PARTY BUNTING   1727
# 4        20725              LUNCH BAG RED RETROSPOT   1638
# ...        ...                                  ...    ...
# 4755     37503      TEA TIME CAKE STAND IN GIFT BOX      1
# 4773     37461                     FUNKY MONKEY MUG      1
# 4775     37474  SET/4 2 TONE EGG SHAPE MIXING BOWLS      1
# 4782     22145      CHRISTMAS CRAFT HEART STOCKING       1
# 4787     21491      SET OF THREE VINTAGE GIFT WRAPS      1
#
# [3958 rows x 3 columns]

# %% [markdown]
# ##merge data

# %%
most_freq.columns = ["StockCode", "freq_Description","count"]
df2 = df1.merge(most_freq,on="StockCode",how= "left")
df2.head()
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 2    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 3    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 4    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#                      freq_Description   count
# 0  WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1  CREAM HANGING HEART T-LIGHT HOLDER     9.0
# 2                                   ?     1.0
# ...

# %%
df2['Description'] = df2['freq_Description']
df2.head()
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365    85123A  CREAM HANGING HEART T-LIGHT HOLDER         6
# 2    536365    85123A                                   ?         6
# 3    536365    85123A         wrongly marked carton 22804         6
# 4    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#                      freq_Description   count
# 0  WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1  CREAM HANGING HEART T-LIGHT HOLDER     9.0
# 2                                   ?     1.0
# ...

# %%
df2.isnull().sum()  # i don't understasn how this working
# Out:
# InvoiceNo                0
# StockCode                0
# Description            112
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          171188
# Country                  0
# freq_Description       112
# count                  112
# dtype: int64

# %% [markdown]
# ## drop null values

# %%
df2.dropna(subset=["Description"],inplace=True)
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description              0
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          171076
# Country                  0
# freq_Description         0
# count                    0
# dtype: int64

# %%
## drop the 2 columns from the data

# %%
df2.drop(columns= ["freq_Description","count"],inplace=True)
df2.head()
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365    85123A  CREAM HANGING HEART T-LIGHT HOLDER         6
# 2    536365    85123A                                   ?         6
# 3    536365    85123A         wrongly marked carton 22804         6
# 4    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df2 = df2.drop(2)

# %%
df2.head()
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365    85123A  CREAM HANGING HEART T-LIGHT HOLDER         6
# 3    536365    85123A         wrongly marked carton 22804         6
# 4    536365     71053                 WHITE METAL LANTERN         6
# 5    536365     71053        WHITE MOROCCAN METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df2.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  710918.000000                         710918  710918.000000
# mean        9.718411  2011-07-05 11:54:21.643930880       4.410163
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-29 15:12:00       1.250000
# 50%         3.000000            2011-07-20 16:17:00       2.100000
# 75%        10.000000            2011-10-19 10:31:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       194.114583                            NaN      84.525666
#
#           CustomerID
# count  539842.000000
# mean    15290.157820
# min     12346.000000
# 25%     13956.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1709.390615

# %%
df2[df2.Quantity<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 196      C536379         D                          Discount        -1
# 209      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 304      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 305      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 306      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 710559   C581499         M                            Manual        -1
# 710781   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 710782   C581568     21258                                 ?        -5
# 710783   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 710784   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df2[df2.UnitPrice<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 391449   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 391450   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 391449  -11062.06         NaN  United Kingdom
# 391450  -11062.06         NaN  United Kingdom

# %%
df3 = df2[(df2.UnitPrice>0)&(df2.Quantity>0)]
df3.head()
df3.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  693944.000000                         693944  693944.000000
# mean       10.873896  2011-07-05 15:59:40.075625216       3.874303
# min         1.000000            2010-12-01 08:26:00       0.001000
# 25%         1.000000            2011-03-29 15:20:00       1.250000
# 50%         4.000000            2011-07-21 10:44:00       2.100000
# 75%        12.000000            2011-10-19 11:49:45       4.130000
# max     80995.000000            2011-12-09 12:50:00   13541.330000
# std       137.669523                            NaN      31.507567
#
#           CustomerID
# count  527364.000000
# mean    15296.792324
# min     12346.000000
# 25%     13969.000000
# 50%     15159.000000
# 75%     16794.000000
# max     18287.000000
# std      1708.783285

# %%
df3.Quantity.quantile(0.9999)
# Out:
# np.float64(1530.1424999989104)

# %%
df3[df3.Quantity>1500]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 6336      536809     84950       ASSORTED COLOUR T-LIGHT HOLDER      1824
# 6472      536830     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 33829     538420     17096    ASSORTED LAQUERED INCENSE HOLDERS      1728
# 42702     539101     22693   GROW A FLYTRAP OR SUNFLOWER IN TIN      2400
# 68298     540815    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# ...          ...       ...                                  ...       ...
# 672274    579498     23084  add stock to allocate online orders      2040
# 672275    579498     23084  allocate stock for dotcom orders ta      2040
# 672276    579498     23084             for online retail orders      2040
# 672277    579498     23084                      temp adjustment      2040
# 709207    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ##Feature engineering : create new columns

# %%
df4 = df3.copy()
df4['Totalprice'] = df4.Quantity * df4.UnitPrice
df4.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365    85123A  CREAM HANGING HEART T-LIGHT HOLDER         6
# 3    536365    85123A         wrongly marked carton 22804         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Totalprice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.3
# 1 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.3
# 3 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.3

# %%
# need to analyse the monthly sales
df4['month'] = df4['InvoiceDate'].dt.month
df4.head()
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365    85123A  CREAM HANGING HEART T-LIGHT HOLDER         6
# 3    536365    85123A         wrongly marked carton 22804         6
# 4    536365     71053                 WHITE METAL LANTERN         6
# 5    536365     71053        WHITE MOROCCAN METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Totalprice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 3 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 5 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#    month
# 0     12
# 1     12
# 3     12
# 4     12
# 5     12

# %% [markdown]
# ## visulalization & EDA

# %% [markdown]
# ##### 1. plot montly sales

# %%
import matplotlib.pyplot as plt

# Grouping the sales by month and summing the Totalprice
monthly_sales = df4.groupby("month")["Totalprice"].sum()


# Plotting
plt.figure(figsize=(10, 6))  # Bigger size
monthly_sales.plot(kind="bar", color="skyblue", edgecolor="black")

# Titles and labels
plt.title("Monthly Sales Overview", fontsize=16)
plt.xlabel("Month", fontsize=14)
plt.ylabel("Total Sales (£)", fontsize=14)
plt.xticks(rotation=45)  # Tilt month names for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ##insight

# %% [markdown]
# TOTAL sales started rising up in august having in novemebr this likely due to holiday

# %%
import matplotlib.pyplot as plt

# 1. Group by country and sum total sales
country_sales = df4.groupby('Country')['Totalprice'].sum().sort_values(ascending=False)

# 2. Get the top 5 countries
top_5_countries = country_sales.head(5)

# 3. Calculate percentage share for the top 5 countries
total_sales_top5 = top_5_countries.sum()
top_5_percentages = (top_5_countries / total_sales_top5) * 100

# 4. Plotting
plt.figure(figsize=(10, 6))
bars = top_5_countries.plot(kind='barh', color='skyblue')  # Horizontal bar chart

# Add percentage labels next to bars
for index, value in enumerate(top_5_countries):
    percentage = top_5_percentages.iloc[index]
    plt.text(value + (total_sales_top5 * 0.01), index, f'{percentage:.1f}%', va='center', fontsize=12)

plt.title('Top 5 Countries by Total Sales', fontsize=16)
plt.xlabel('Total Sales (£)', fontsize=14)
plt.ylabel('Country', fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
